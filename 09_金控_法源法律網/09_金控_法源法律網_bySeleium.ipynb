# %% [raw]
# '''
# Project Name: 法源法律網
# CTM Name    :
# Crawl Cycle : Daily
# Main Website: http://www.lawbank.com.tw/news/NewsSearch.aspx?TY=19 (法規新訊)
#               http://www.lawbank.com.tw/news/NewsSearch.aspx?TY=20 (判解新訊)
#               http://www.lawbank.com.tw/news/NewsSearch.aspx?TY=21 (函釋新訊)
#               http://www.lawbank.com.tw/news/NewsSearch.aspx?TY=22 (法規草案)
# Description : 針對法源法律網-法律新訊，每日取得法規異動資訊
# Author      : 林竣昇
# Update Date : 2018/12/21
# '''

# %%
import header
import logging

from selenium import webdriver 
from selenium.webdriver.support.ui import WebDriverWait
import SeleniumUtil

import datetime
import pandas as pd
import traceback
from bs4 import BeautifulSoup

import os
import requests

# %%
TempPath = "./Temp/"  # browser file
FinalPath = "./Result/" # project file
lastResultPath = "./CrawlList/"
lastResultName = "lastResult"

# %%
def getDetailFromContent(soup, tempMap, tabNumber, subColName):
    
    temp = soup.select("pre:nth-of-type(1)")[0].text.strip()
    if tabNumber == 19:
        # 發文字號
        serialNumber = temp.replace("\n", "").strip()
        strPos = serialNumber.find("日")
        endPos = serialNumber.rfind("號令")
        if strPos != -1 & endPos != -1:
            strPos += 1
            endPos += 2
            serialNumber = serialNumber[strPos:endPos]
        else:
            serialNumber = ""

        # 發文日期
        date = soup.select("#ctl00_cphMain_lblndate")[0].text.strip()

        # 相關法條
        relatedLaws = soup.select("#ctl00_cphMain_relaData a")
        relatedLaw = ", ".join(e.text.strip() for e in relatedLaws)
            
    else:
        
        # 裁判字號
        strPos = temp.find(subColName + "字號：")
        if strPos != -1:
            strPos += 5
            endPos = strPos + temp[strPos:].find("：") - 4
            serialNumber = temp[strPos:endPos].strip()
        else:
            serialNumber = ""


        # 裁判日期
        strPos = temp.find(subColName + "日期：")
        if strPos != -1:
            strPos += 5
            endPos = strPos + temp[strPos:].find("：") - 4
            date = temp[strPos:endPos]
        else:
            date = ""

        # 相關法條
        strPos = temp.find("相關法條：")
        if strPos != -1:
            strPos += 5
            endPos = strPos + temp[strPos:].find("：") - 4
            relatedLaws = temp[strPos:endPos].split("\n")
            relatedLaw = ", ".join(e.strip() for e in relatedLaws)[:-2]
        else:
            relatedLaws = soup.select("#ctl00_cphMain_relaData a")
            relatedLaw = ", ".join(e.text.strip() for e in relatedLaws)
            
                
    
        
    tempMap["發文字號"] = serialNumber
    tempMap["發文日期"] = date
    tempMap["相關法條"] = relatedLaw
    
    return tempMap

# %%
def request2soup(url):
    res = requests.get(url)
    res.encoding = "utf-8"
    soup = BeautifulSoup(res.text, "html.parser", from_encoding = "utf-8")
    return soup

# %%
def parsingDetail(df, FinalPath, tabNumber):
    
    if tabNumber == 20:
        subColName = "裁判"
    elif tabNumber == 22:
        subColName = "提案"
    else:
        subColName = "發文"
    
    df_detail = pd.DataFrame(columns = ["標題", "全文內容", subColName + "字號", subColName + "日期", "相關法條", "附件"])

    for link in df["網頁連結"]:
        try:
            print("擷取網址：" + link)
            soup = request2soup(link)

            # 主旨
            title = soup.select("#ctl00_cphMain_lblSubject")[0].text.strip()

            # 全文內容
            content = soup.select("#pageNews")[0].text.strip()
            content = content.split("第 一 章")[0].strip() # for 2018-11-26 電信管理法之例外處理
            
            tempMap = {"標題" : title, 
                       "全文內容" : content,
                       "附件" : ""}
            
            tempMap = getDetailFromContent(soup, tempMap, tabNumber, subColName)
            
            df_detail = df_detail.append(tempMap, ignore_index = True)

            print("爬取成功")
        except:
            logging.error("爬取內文失敗")
            logging.error("失敗連結：" + link)
            traceback.print_exc()

        print("\n")
    return df_detail

# %%
def outputCsv(df, fileName, path):
    # 若目錄不存在，建立目錄
    if not os.path.isdir(path):
        os.mkdir(path)
    df.to_csv(path + fileName + ".csv", index = False, encoding = "utf_8_sig")

# %%
def parsingTitle(driver, checkRange):
    try:
        # 取得上次爬網結果
        if os.path.isfile(lastResultPath):
            lastResult = pd.read_csv(lastResultPath)
        else:
            lastResult = pd.DataFrame()

        # 爬網日期區間為一個禮拜
        endDate = datetime.date.today()
        strDate = (endDate - datetime.timedelta(days = checkRange)).isoformat()
        
        ending = False
        nowPage = 1
        df = pd.DataFrame(columns = ["爬文日期", "發文日期", "標題", "網頁連結"])

        # actions
        while True:
            try:
                dates = driver.find_elements_by_css_selector(".tdDate")
                dates = [x.text for x in dates] 

                titles = driver.find_elements_by_css_selector(".tdSubject")
                titles = [x.text for x in titles] 

                links = driver.find_elements_by_css_selector(".tdSubject a")
                links = [x.get_attribute("href") for x in links]

                show = pd.Series([False] * len(dates))
                for idx in range(len(dates)):
                    date = dates[idx]
                    if date < strDate: # 若發文日期小於開始日期, 則結束爬取主旨
                        ending = True
                        break
                    show[idx] = True
                    
                nowDates = [str(endDate.year) + "/" + str(endDate.month) + "/" + str(endDate.day)] * len(dates)
                d = {"爬文日期" : nowDates, "發文日期" : dates, "標題" : titles, "網頁連結" : links}
                df = df.append(pd.DataFrame(data = d)[show])  # append page

                # 若結束爬取主旨, 停止爬取剩下的 page
                if ending:
                    break
                    
                # 下一頁
                goNext = driver.find_elements_by_css_selector("#ctl00_cphMain_PagerTop_butNext")[0]
                if goNext.get_attribute("href") == None: # 最後一頁不執行點擊下一頁
                    break
                goNext.click() # 下一頁
                nowPage += 1
            except:
                logging.error("爬取第 %s 頁主旨發生錯誤" %str(nowPage + 1))
                traceback.print_exc()
                
        outputCsv(df, lastResultName, lastResultPath)

        if not lastResult.empty:
            # 若與上次發文日期和標題相同，則跳至下一筆
            for i in range(len(df)):
                for j in range(len(lastResult)):
                    if (df["發文日期"][i] == lastResult["發文日期"][j]) & (df["標題"][i] == lastResult["標題"][j]): 
                        df.drop(i, inplace = True)
                        break

        if len(df) == 0:
            logging.critical("%s 至 %s 間無資料更新" %(strDate, endDate))
        else:
            df.index = [i for i in range(df.shape[0])] # reset 

        return df
    
    except:
        logging.error("爬取主旨列表失敗")
        traceback.print_exc()
        return pd.DataFrame(columns = ["爬文日期", "發文日期", "標題", "網頁連結"])

# %%
def main(url, tabNumber, checkRange = 7):
    
    logging.critical("\n")
    logging.critical("爬網開始......")
    logging.critical("目標網址：" + url)
    
    strTime = datetime.datetime.now()
    logging.critical("開始時間：" + strTime.strftime("%Y/%m/%d %H:%M:%S"))
    
    DownloadTool = SeleniumUtil.ChromeDownload()
    DownloadTool.setDownLoadTempPath(TempPath)
    DownloadTool.setDownLoadFinalPath(FinalPath)
    chrome_options = DownloadTool.getChromeOptions()
    driver = webdriver.Chrome(chrome_options = chrome_options) # open chrome browser with Options
    
    try:
        if tabNumber >= 19 and tabNumber <= 22 and isinstance(tabNumber, int):
            url = url + str(tabNumber)
        else:
            raise ValueError("tabNumber 必須為 19 到 22 的整數")
        
        driver.get(url)
        df_1 = parsingTitle(driver, checkRange)
        if len(df_1) != 0:
            outputCsv(df_1, "第一層結果", FinalPath)
        
            df_2 = parsingDetail(df_1, tabNumber, FinalPath)
            outputCsv(df_2, "第二層結果", FinalPath)
    except:
        logging.error("執行爬網作業失敗")
        traceback.print_exc()

    endTime = datetime.datetime.now()
    logging.critical("結束時間：" + endTime.strftime("%Y/%m/%d %H:%M:%S"))
    logging.critical("執行時間：" + str((endTime - strTime).seconds) + " 秒")
    logging.critical("輸出筆數：" + str(len(df_1)) + " 筆")
    logging.critical("爬網結束......\n")

# %%
if __name__ == "__main__":
    url = "http://www.lawbank.com.tw/news/NewsSearch.aspx?TY="
    main(url, 19, 30)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: use options instead of chrome_options
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=1&NID=157144.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:179: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=2&NID=157143.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=3&NID=157138.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=4&NID=157137.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=5&NID=157136.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=6&NID=157135.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=7&NID=157134.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=8&NID=157133.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=9&NID=157132.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=10&NID=157131.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=11&NID=157130.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=12&NID=157109.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=13&NID=157089.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=14&NID=157088.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=15&NID=157087.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=16&NID=157086.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=17&NID=157085.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=18&NID=157084.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=19&NID=157083.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=20&NID=157073.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=21&NID=157072.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=22&NID=157071.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=23&NID=157070.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=24&NID=157069.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=25&NID=157064.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=26&NID=157062.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=27&NID=157061.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=28&NID=157045.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=29&NID=157044.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=30&NID=157043.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=31&NID=157042.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=32&NID=157041.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=33&NID=157039.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=34&NID=157036.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=35&NID=157035.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=36&NID=157021.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=37&NID=157020.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=38&NID=157017.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=39&NID=157016.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=40&NID=157006.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=41&NID=156999.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=42&NID=156998.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=43&NID=156997.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=44&NID=156996.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=45&NID=156995.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=46&NID=156994.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=47&NID=156993.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=48&NID=156992.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=49&NID=156991.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=50&NID=156989.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=51&NID=156988.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=52&NID=156987.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=53&NID=156983.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=54&NID=156982.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=55&NID=156981.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=56&NID=156976.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=57&NID=156975.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=58&NID=156974.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=59&NID=156970.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=60&NID=156969.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=61&NID=156968.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=62&NID=156960.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=63&NID=156936.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=64&NID=156929.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=65&NID=156926.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=66&NID=156925.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=67&NID=156924.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=68&NID=156923.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=69&NID=156920.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=70&NID=156919.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=71&NID=156918.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=72&NID=156917.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=73&NID=156916.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=74&NID=156906.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=75&NID=156899.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=76&NID=156893.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=77&NID=156891.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=78&NID=156884.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=79&NID=156880.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=80&NID=156876.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=81&NID=156875.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=82&NID=156874.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=83&NID=156873.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=84&NID=156872.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=85&NID=156871.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=86&NID=156870.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=87&NID=156869.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=88&NID=156864.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=89&NID=156860.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=90&NID=156858.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=91&NID=156845.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=92&NID=156844.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=93&NID=156828.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=94&NID=156827.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=95&NID=156826.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=96&NID=156819.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=97&NID=156818.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=98&NID=156817.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=99&NID=156816.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=100&NID=156815.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=101&NID=156814.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=102&NID=156811.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=103&NID=156809.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=104&NID=156808.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=105&NID=156799.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=106&NID=156798.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=107&NID=156795.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=108&NID=156794.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=109&NID=156793.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=110&NID=156787.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=111&NID=156786.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=112&NID=156785.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=113&NID=156784.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=114&NID=156783.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=115&NID=156781.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=116&NID=156780.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=117&NID=156779.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=118&NID=156776.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=119&NID=156775.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=120&NID=156774.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=121&NID=156773.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=122&NID=156772.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=123&NID=156771.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=124&NID=156770.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=125&NID=156769.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=126&NID=156768.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=127&NID=156767.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=128&NID=156748.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=129&NID=156746.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=130&NID=156745.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=131&NID=156744.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=132&NID=156743.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=133&NID=156739.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=134&NID=156733.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=135&NID=156732.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=136&NID=156731.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=137&NID=156724.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=138&NID=156723.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=139&NID=156722.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=140&NID=156711.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=141&NID=156701.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=142&NID=156700.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=143&NID=156699.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=144&NID=156694.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=145&NID=156692.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=146&NID=156691.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=147&NID=156688.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=148&NID=156687.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=149&NID=156684.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=150&NID=156677.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=151&NID=156676.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=152&NID=156674.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=153&NID=156673.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=154&NID=156672.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=155&NID=156671.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=156&NID=156670.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=157&NID=156669.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=158&NID=156668.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=159&NID=156667.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=160&NID=156666.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=161&NID=156665.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=162&NID=156664.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=163&NID=156663.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=164&NID=156662.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=165&NID=156661.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=166&NID=156660.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=167&NID=156659.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=168&NID=156658.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=169&NID=156653.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=170&NID=156652.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=171&NID=156650.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=172&NID=156649.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=173&NID=156643.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=174&NID=156640.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=175&NID=156639.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=176&NID=156638.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=177&NID=156637.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=178&NID=156635.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=179&NID=156630.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=180&NID=156629.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=181&NID=156628.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=182&NID=156617.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=183&NID=156616.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=184&NID=156611.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=185&NID=156608.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=186&NID=156607.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=187&NID=156605.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=188&NID=156604.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=189&NID=156600.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=190&NID=156599.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=191&NID=156598.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=192&NID=156597.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=193&NID=156596.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=194&NID=156595.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=195&NID=156594.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=196&NID=156592.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=197&NID=156591.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=198&NID=156589.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=199&NID=156588.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=200&NID=156587.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=201&NID=156577.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=202&NID=156575.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=203&NID=156574.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=204&NID=156573.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=205&NID=156569.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=206&NID=156565.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=207&NID=156564.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=208&NID=156563.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=209&NID=156558.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=210&NID=156546.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=211&NID=156545.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=212&NID=156562.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=213&NID=156561.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=214&NID=156560.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=215&NID=156538.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=216&NID=156537.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=217&NID=156536.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=218&NID=156534.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=219&NID=156512.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=220&NID=156511.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=221&NID=156510.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=222&NID=156509.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=223&NID=156508.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=224&NID=156507.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=225&NID=156506.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=226&NID=156505.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=227&NID=156504.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=228&NID=156499.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=229&NID=156498.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=230&NID=156497.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=231&NID=156493.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=232&NID=156491.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=233&NID=156488.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=234&NID=156487.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=235&NID=156531.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=236&NID=156483.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=237&NID=156465.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=238&NID=156461.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=239&NID=156460.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=240&NID=156459.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=241&NID=156457.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=242&NID=156455.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=243&NID=156453.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=244&NID=156436.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=245&NID=156433.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=246&NID=156429.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=247&NID=156428.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=248&NID=156427.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=249&NID=156426.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=250&NID=156424.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=251&NID=156423.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=252&NID=156422.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=253&NID=156421.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=254&NID=156420.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=255&NID=156419.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=256&NID=156418.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=257&NID=156417.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=258&NID=156416.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=259&NID=156415.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=260&NID=156413.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=261&NID=156435.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=262&NID=156434.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=263&NID=156387.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=264&NID=156386.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=265&NID=156385.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=266&NID=156382.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
#
#
# 擷取網址：https://www.lawbank.com.tw/news/NewsContent.aspx?AID=267&NID=156379.00&kw=&TY=19&sd=&ed=&total=60359&NCLID=&lsid=
# 爬取成功
