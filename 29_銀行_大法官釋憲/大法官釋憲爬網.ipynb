# %% [raw]
# '''
# Project Name: moj project
# Crawl Cycle: Daily
# Main Website: https://www.judicial.gov.tw/constitutionalcourt/p03_0001.asp
# author      : 林德昌
# date        : 2018/12/17
# description : 抓取大法官釋憲每天發布的最新消息
# '''

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import header
import logging
import re
import datetime
import traceback # 印log
import os
TempPath = "./Temp"  # browser file
FinalPath = "./Result" # project file
lastResultPath = "./CrawlList/lastResult.csv"

# %%
def downloadFile(finalPath, title, fileUrls, fileNames): # for download pdf or doc
    target = finalPath + '/' + title[:30].strip()
    # 若目錄不存在，建立目錄
    if not os.path.isdir(target):
        os.makedirs(target)
    for file_url, fileName in zip(fileUrls, fileNames):
        try:
            response = requests.get(file_url, stream="TRUE")
            # 放置資料夾路徑 + 檔名 + 副檔名
            downloadFile = target + '/' + fileName.strip() + re.findall(r'\..+', response.headers['Content-Disposition'])[0]
            logging.info(downloadFile + '\r\n')
            with open(downloadFile,'wb') as file:
                for data in response.iter_content():
                    file.write(data)
        except:
            logging.error("爬取檔案失敗")
            logging.error("失敗連結：" + file_url)

# %%
def dataProcess_Detail(soup):
    result = dict()
    fileUrlRoot = 'https://www.judicial.gov.tw/constitutionalcourt/'
    result['fileNames'] = [e.text for e in soup.select('.content_table a')]
    logging.info(result['fileNames'])
    result['fileUrls'] = [fileUrlRoot + e.get('href') for e in soup.select('.content_table a')]
    result['content0'] = [e.text.strip().replace('\xa0','').replace('\r\n\t\t\t\t\t','') for e in soup.select('.content_table td')][0] # 解釋字號
    result['content1'] = [e.text.strip().replace('\xa0','').replace('\r\n\t\t\t\t\t','') for e in soup.select('.content_table td')][1] # 解釋公布院令
    result['content2'] = [e.text.strip() for e in soup.select('.content_table td')][2] # 解釋爭點
    result['content3'] = [e.text.strip().replace('\u3000','') for e in soup.select('.content_table td')][3] # 解釋文
    result['content4'] = [e.text.strip().replace('\u3000','') for e in soup.select('.content_table td')][4] # 理由書
    result['issue_date'] = re.findall(r'中華民國.+?日', result['content1'])[0]
    
    return result

# %%
def parsingDetail(df, finalPath): 
    df2 = pd.DataFrame(columns = ["標題", "發文日期", "附件", "發文字號(解釋字號)","解釋公布院令","解釋爭點", "解釋文", "理由書", "相關法條"])
    for index, row in df.iterrows():
        try:
            title = row['標題']
            logging.info(title)
            link = row['內文連結']
            soup = request2soup(link)
            result = dataProcess_Detail(soup)
            fileNames = result['fileNames'] 
            if len(fileNames) != 0:
                downloadFile(finalPath, title, result['fileUrls'], fileNames)
            d = {'標題': title, '發文日期':result['issue_date'], '附件':','.join(fileNames), '發文字號(解釋字號)':result['content0'],
                 "解釋公布院令":result['content1'], '解釋爭點':result['content2'], "解釋文": result['content3'], '理由書':result['content4'],
                 '相關法條':''}
            df2= df2.append(d, ignore_index=True)
        except:
            logging.error("爬取內文失敗")
            logging.error("失敗連結：" + link)
            traceback.print_exc()
    return df2

# %%
def outputCsv(df, fileName, path):
    # 若目錄不存在，建立目錄
    if not os.path.isdir(path):
        os.mkdir(path)
    df.to_csv(path + "/" + fileName + ".csv", index = False, encoding = "utf_8_sig")

# %%
def compareTo(strDate, endDate):
    strDate = re.sub(r'(/|-|\.)', '-', strDate)
    endDate = re.sub(r'(/|-|\.)', '-', endDate)
    if int(re.split('-', strDate)[0]) < 1911:
        strDate = datetime.datetime.strptime(str(int(re.sub('-', '', strDate)) + 19110000), "%Y%m%d").strftime("%Y-%m-%d")
    if int(re.split('-', endDate)[0]) < 1911:
        endDate = datetime.datetime.strptime(str(int(re.sub('-', '', endDate)) + 19110000), "%Y%m%d").strftime("%Y-%m-%d")
    try:
        strDate = datetime.datetime.strptime(strDate, "%Y-%m-%d")
        endDate = datetime.datetime.strptime(endDate, "%Y-%m-%d")

    except:
        logging.error('compareTo(strDate, endDate):')
        logging.error("日期格式錯誤：strDate = %s, endDate = %s" %(strDate, endDate))
        traceback.print_exc()
        return
    if strDate < endDate:
        return 1
    elif strDate == endDate:
        return 0
    else:
        return -1

# %%
def parsingTitle(soup, checkRange):
    try:
        # 取得上次爬網結果
        if os.path.isfile(lastResultPath):
            lastResult = pd.read_csv(lastResultPath)
        else:
            lastResult = pd.DataFrame()
        
        # 爬網日期區間為一個禮拜
        endDate = datetime.date.today()
        strDate = (endDate - datetime.timedelta(days = checkRange)).isoformat()
        
        nowPage = 1
        df = pd.DataFrame(columns=['爬網日期','發文日期','標題','內文連結','大法官解釋字號'])
        while True:
            index = 0 # css selector上的資料序號
            while True:
                try:
                    title = [e.text.strip().replace('\r\r\n','') for e in soup.select('#AutoNumber2 td[width="84%"] p font')][index]
                    if title == []:  # 當title抓不到東西的時候代表抓完資料了
                        break
                    link = [('https://www.judicial.gov.tw/constitutionalcourt/' + e.get('href')) for e in soup.select('#AutoNumber2 td[width="16%"] p a')][index]
                    date = [re.findall(r'\(.+\)', e.text)[0][1:-1] for e in soup.select('#AutoNumber2 td[width="16%"] p a')][index]
                    serno = [e.text for e in soup.select('#AutoNumber2 td[width="16%"] p a')][index]
                    if compareTo(date, strDate) > 0:
                        break
                    tempDf = {'爬網日期': endDate, '發文日期': date,'標題': title, '內文連結': link, '大法官解釋字號':serno}
                    df = df.append(tempDf, ignore_index=True)
                    index += 1
                except:
                    logging.error("爬取第 %s 頁第 %s 筆主旨發生錯誤" %(nowPage, index + 1))
                    traceback.print_exc()
            if compareTo(date, strDate) > 0:   # 當日期起始大於發文日期時就停止
                break
            nowPage += 1
            soup = request2soup(url + "&TPage={}".format(nowPage))  
            
        df.index = [i for i in range(df.shape[0])] # reset Index 
        
        
        if not lastResult.empty:
            for index, row in df.iterrows():
                if (row['發文日期'] in list(lastResult['發文日期'])) and (row['大法官解釋字號'] in list(lastResult['大法官解釋字號'])):
                    df.drop(index, inplace = True)

        if len(df) == 0:
            logging.critical("%s 至 %s 間無資料更新" %(strDate, endDate))
        else:
            df.index = [i for i in range(df.shape[0])] # reset 
            outputCsv(df, "lastResult", "./CrawlList")
    except:
        logging.error("爬取主旨列表失敗")
        traceback.print_exc()
    
    return df

# %%
def request2soup(url):
    res = requests.get(url)
    res.encoding = 'big5'
    soup = BeautifulSoup(res.text,'html.parser')
    return soup

# %%
def main(url, checkRange = 35):
    
    logging.critical("\n")
    logging.critical("爬網開始......")
    logging.critical("目標網址：" + url)
    
    strTime = datetime.datetime.now()
    logging.critical("開始時間：" + strTime.strftime("%Y/%m/%d %H:%M:%S"))
    try:
        soup = request2soup(url)
        df_1 = parsingTitle(soup, checkRange)
        if len(df_1) == 0:
            return
        outputCsv(df_1, "第一層結果", FinalPath)

        df_2 = parsingDetail(df_1, FinalPath)
        outputCsv(df_2, "第二層結果", FinalPath)
    except:
        logging.error("執行爬網作業失敗")
        traceback.print_exc()
        
    endTime = datetime.datetime.now()
    logging.critical("結束時間：" + endTime.strftime("%Y/%m/%d %H:%M:%S"))
    logging.critical("執行時間：" + str((endTime - strTime).seconds) + " 秒")
    logging.critical("輸出筆數：" + str(len(df_1)) + " 筆")
    logging.critical("爬網結束......")

# %%
if __name__ == "__main__":
    url = "https://www.judicial.gov.tw/constitutionalcourt/p03_0001.asp"
    main(url)
# Out:
# 2019-01-08 17:14:45,429 - <ipython-input-9-bf504eb000b2>[line:3] - CRITICAL:
#
# 2019-01-08 17:14:45,435 - <ipython-input-9-bf504eb000b2>[line:4] - CRITICAL: 爬網開始......
# 2019-01-08 17:14:45,438 - <ipython-input-9-bf504eb000b2>[line:5] - CRITICAL: 目標網址：https://www.judicial.gov.tw/constitutionalcourt/p03_0001.asp
# 2019-01-08 17:14:45,440 - <ipython-input-9-bf504eb000b2>[line:8] - CRITICAL: 開始時間：2019/01/08 17:14:45
# 2019-01-08 17:14:47,227 - <ipython-input-4-b2d10b4e3065>[line:6] - INFO: 未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條之1第3項前段規定行使優先購買權所生爭議，其訴訟應由普通法院或行政法院審判？
# 2019-01-08 17:14:47,486 - <ipython-input-3-1181cbb3df10>[line:5] - INFO: ['黃大法官璽君提出之協同意見書', '羅大法官昌發提出之協同意見書', '林大法官俊益提出之協同意見書', '黃大法官瑞明提出之協同意見書', '詹大法官森林提出之協同意見書', '黃大法官虹霞提出，蔡大法官明誠加入之不同意見書', '土地法第73條之1第1項、第2項、第4項(100.06.15)', '司法院釋字第466號解釋', '司法院釋字第695號解釋', '司法院釋字第758號解釋', '司法院釋字第759號解釋', '司法院釋字第772號解釋', '釋字第773號解釋摘要', '臺北高等行政法院第七庭聲請書']
# 2019-01-08 17:14:47,681 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/黃大法官璽君提出之協同意見書.docx
#
# 2019-01-08 17:14:48,171 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/羅大法官昌發提出之協同意見書.docx
#
# 2019-01-08 17:14:48,784 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/林大法官俊益提出之協同意見書.doc
#
# 2019-01-08 17:14:50,407 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/黃大法官瑞明提出之協同意見書.docx
#
# 2019-01-08 17:14:51,037 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/詹大法官森林提出之協同意見書.docx
#
# 2019-01-08 17:14:51,826 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/黃大法官虹霞提出，蔡大法官明誠加入之不同意見書.docx
#
# 2019-01-08 17:14:52,634 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:14:52,636 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40970
# 2019-01-08 17:14:52,838 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:14:52,841 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40971
# 2019-01-08 17:14:53,039 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:14:53,040 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40972
# 2019-01-08 17:14:53,495 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:14:53,497 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40973
# 2019-01-08 17:14:53,727 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:14:53,729 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40974
# 2019-01-08 17:14:53,972 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:14:53,976 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40975
# 2019-01-08 17:14:54,170 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/釋字第773號解釋摘要.docx
#
# 2019-01-08 17:14:54,723 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/未辦理繼承登記土地或建築改良物之合法使用人，依土地法第73條/臺北高等行政法院第七庭聲請書.pdf
#
# 2019-01-08 17:15:03,385 - <ipython-input-4-b2d10b4e3065>[line:6] - INFO: 人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之不動產經否准所生爭議，其訴訟應由普通法院或行政法院審判？
# 2019-01-08 17:15:03,651 - <ipython-input-3-1181cbb3df10>[line:5] - INFO: ['羅大法官昌發提出之協同意見書', '林大法官俊益提出之協同意見書', '詹大法官森林提出之協同意見書', '黃大法官瑞明提出之部分協同部分不同意見書', '黃大法官璽君提出之不同意見書', '黃大法官虹霞提出，蔡大法官明誠加入之不同意見書', '國有財產法第52條之2(107.11.21)', '司法院大法官審理案件法第7條(82.02.03)', '民事訴訟法第182條之1(107.11.28)', '司法院釋字第371號解釋', '司法院釋字第466號解釋', '司法院釋字第572號解釋', '司法院釋字第691號解釋', '司法院釋字第695號解釋', '司法院釋字第758號解釋', '司法院釋字第759號解釋', '釋字第772號解釋摘要', '臺灣臺北地方法院民事第五庭金股法官聲請書']
# 2019-01-08 17:15:03,771 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/羅大法官昌發提出之協同意見書.docx
#
# 2019-01-08 17:15:04,290 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/林大法官俊益提出之協同意見書.doc
#
# 2019-01-08 17:15:05,544 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/詹大法官森林提出之協同意見書.docx
#
# 2019-01-08 17:15:06,031 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/黃大法官瑞明提出之部分協同部分不同意見書.docx
#
# 2019-01-08 17:15:06,616 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/黃大法官璽君提出之不同意見書.docx
#
# 2019-01-08 17:15:07,080 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/黃大法官虹霞提出，蔡大法官明誠加入之不同意見書.docx
#
# 2019-01-08 17:15:07,926 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:07,927 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40976
# 2019-01-08 17:15:08,208 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:08,210 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40977
# 2019-01-08 17:15:08,527 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:08,530 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40978
# 2019-01-08 17:15:08,716 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:08,722 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40979
# 2019-01-08 17:15:08,996 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:08,998 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40980
# 2019-01-08 17:15:09,189 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:09,191 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40981
# 2019-01-08 17:15:09,412 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:09,419 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40982
# 2019-01-08 17:15:09,579 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:09,582 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40983
# 2019-01-08 17:15:09,833 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:09,835 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40984
# 2019-01-08 17:15:10,059 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:10,061 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40985
# 2019-01-08 17:15:10,236 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/釋字第772號解釋摘要.docx
#
# 2019-01-08 17:15:10,920 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/人民依國有財產法第52條之2規定，申請讓售國有非公用財產類之/臺灣臺北地方法院民事第五庭金股法官聲請書.pdf
#
# 2019-01-08 17:15:25,914 - <ipython-input-4-b2d10b4e3065>[line:6] - INFO: 1.最高法院40年台上字第730號民事判例及司法院37年院解字第3997號解釋認繼承回復請求權於時效完成後，真正繼承人喪失其原有繼承權，並由表見繼承人取得其繼承權，是否違憲？
# 2.司法院院字及院解字解釋，如涉及審判上之法律見解，法官於審判案件時，是否受其拘束？
# 2019-01-08 17:15:26,286 - <ipython-input-3-1181cbb3df10>[line:5] - INFO: ['許大法官志雄提出，黃大法官昭元加入之協同意見書', '黃大法官瑞明提出之協同意見書', '詹大法官森林提出之協同意見書', '羅大法官昌發提出之部分不同部分協同意見書', '黃大法官虹霞提出之部分不同部分協同意見書', '蔡大法官明誠提出，黃大法官虹霞、吳大法官陳鐶加入意見書五部分之部分不同部分協同意見書', '陳大法官碧玉提出之部分不同意見書', '吳大法官陳鐶提出之部分不同意見書', '憲法第15條、第78條及第79條第2項(36.01.01)', '司法院釋字第107號解釋', '司法院釋字第108號解釋', '司法院釋字第154號解釋', '司法院釋字第164號解釋', '司法院釋字第174號解釋', '司法院釋字第185號解釋', '司法院釋字第216號解釋', '司法院釋字第271號解釋', '司法院釋字第308號解釋', '司法院釋字第374號解釋', '司法院釋字第399號解釋', '司法院釋字第437號解釋', '司法院釋字第569號解釋', '司法院釋字第582號解釋', '司法院釋字第596號解釋', '司法院釋字第622號解釋', '司法院釋字第675號解釋', '司法院釋字第679號解釋', '司法院釋字第698號解釋', '司法院釋字第703號解釋', '司法院釋字第709號解釋', '司法院釋字第732號解釋', '司法院釋字第763號解釋', '民法第125、144條(18.05.23)', '民法第310條(18.11.22)', '民法第801條(18.11.30)', '民法第1146條、第1147條及第1148條第1項(19.12.26)', '民法第1145條(74.06.03)', '民法第767條及第759條之1(98.01.23)', '司法院大法官審理案件法第5條第1項第2款及第7條第1項第2款(82.02.03)', '釋字第771號解釋摘要', '陳林照聲請書', '陳林照聲請補充理由書', '駱安婕聲請書', '最高法院102年度台上字第2449號民事判決', '最高法院103年度台上字第1671號民事判決']
# 2019-01-08 17:15:26,438 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/許大法官志雄提出，黃大法官昭元加入之協同意見書.docx
#
# 2019-01-08 17:15:27,188 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/黃大法官瑞明提出之協同意見書.docx
#
# 2019-01-08 17:15:27,809 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/詹大法官森林提出之協同意見書.docx
#
# 2019-01-08 17:15:28,451 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/羅大法官昌發提出之部分不同部分協同意見書.docx
#
# 2019-01-08 17:15:29,118 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/黃大法官虹霞提出之部分不同部分協同意見書.docx
#
# 2019-01-08 17:15:29,712 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/蔡大法官明誠提出，黃大法官虹霞、吳大法官陳鐶加入意見書五部分之部分不同部分協同意見書.docx
#
# 2019-01-08 17:15:30,912 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/陳大法官碧玉提出之部分不同意見書.docx
#
# 2019-01-08 17:15:31,714 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/吳大法官陳鐶提出之部分不同意見書.docx
#
# 2019-01-08 17:15:32,417 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:32,421 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40872
# 2019-01-08 17:15:32,599 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:32,601 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40873
# 2019-01-08 17:15:32,771 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:32,775 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40874
# 2019-01-08 17:15:32,993 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:32,994 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40875
# 2019-01-08 17:15:33,173 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:33,175 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40876
# 2019-01-08 17:15:33,399 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:33,401 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40877
# 2019-01-08 17:15:33,705 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:33,709 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40878
# 2019-01-08 17:15:33,919 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:33,922 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40879
# 2019-01-08 17:15:34,107 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:34,109 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40880
# 2019-01-08 17:15:34,290 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:34,292 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40881
# 2019-01-08 17:15:34,512 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:34,514 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40882
# 2019-01-08 17:15:34,786 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:34,788 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40883
# 2019-01-08 17:15:35,046 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:35,049 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40884
# 2019-01-08 17:15:35,250 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:35,251 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40885
# 2019-01-08 17:15:35,550 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:35,552 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40886
# 2019-01-08 17:15:35,798 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:35,800 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40887
# 2019-01-08 17:15:36,048 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:36,051 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40888
# 2019-01-08 17:15:36,245 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:36,246 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40889
# 2019-01-08 17:15:36,416 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:36,417 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40890
# 2019-01-08 17:15:36,620 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:36,622 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40891
# 2019-01-08 17:15:36,956 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:36,957 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40892
# 2019-01-08 17:15:37,204 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:37,207 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40893
# 2019-01-08 17:15:37,401 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:37,403 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40894
# 2019-01-08 17:15:37,654 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:37,656 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40895
# 2019-01-08 17:15:38,022 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:38,024 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40896
# 2019-01-08 17:15:38,283 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:38,285 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40897
# 2019-01-08 17:15:38,596 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:38,600 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40898
# 2019-01-08 17:15:39,067 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:39,069 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40899
# 2019-01-08 17:15:39,278 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:39,282 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40900
# 2019-01-08 17:15:39,545 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:39,547 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40901
# 2019-01-08 17:15:39,807 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:15:39,809 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/RelaData.asp?linkid=40902
# 2019-01-08 17:15:39,962 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/釋字第771號解釋摘要.docx
#
# 2019-01-08 17:15:40,765 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/陳林照聲請書.pdf
#
# 2019-01-08 17:16:04,327 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/陳林照聲請補充理由書.pdf
#
# 2019-01-08 17:16:13,583 - <ipython-input-2-822a3ebd0246>[line:11] - INFO: ./Result/1.最高法院40年台上字第730號民事判例及司法院37年院解/駱安婕聲請書.pdf
#
# 2019-01-08 17:16:19,139 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:16:19,141 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/BToUTrans.aspx?v_court=TPS+%B3%CC%B0%AA%AAk%B0%7C&v_sys=V&jud_year=102&jud_case=%A5x%A4W&jud_no=2449&keyword=&sdate=&edate=
# 2019-01-08 17:16:19,325 - <ipython-input-2-822a3ebd0246>[line:16] - ERROR: 爬取檔案失敗
# 2019-01-08 17:16:19,327 - <ipython-input-2-822a3ebd0246>[line:17] - ERROR: 失敗連結：https://www.judicial.gov.tw/constitutionalcourt/BToUTrans.aspx?v_court=TPS+%B3%CC%B0%AA%AAk%B0%7C&v_sys=V&jud_year=103&jud_case=%A5x%A4W&jud_no=1671&keyword=&sdate=&edate=
# 2019-01-08 17:16:19,345 - <ipython-input-9-bf504eb000b2>[line:23] - CRITICAL: 結束時間：2019/01/08 17:16:19
# 2019-01-08 17:16:19,347 - <ipython-input-9-bf504eb000b2>[line:24] - CRITICAL: 執行時間：93 秒
# 2019-01-08 17:16:19,348 - <ipython-input-9-bf504eb000b2>[line:25] - CRITICAL: 輸出筆數：3 筆
# 2019-01-08 17:16:19,349 - <ipython-input-9-bf504eb000b2>[line:26] - CRITICAL: 爬網結束......
