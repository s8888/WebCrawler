# %% [raw]
# '''
# Project Name: bankingGov project
# Crawl Cycle: Daily
# Main Website: https://www.moj.gov.tw/lp-22-001-1-20.html
# author      : 林德昌
# date        : 2018/10/16
# description : 抓取法務部每天發布的最新消息
# '''

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import header
import logging
import re
import datetime
import traceback # 印log
import os
TempPath = "./Temp"  # browser file
FinalPath = "./Result" # project file
lastResultPath = "./CrawlList/lastResult.csv"

# %%
def downloadFile(finalPath, title, fileUrls, fileNames): # for download pdf or doc
    target = finalPath + '/' + title[:30].strip()
    # 若目錄不存在，建立目錄
    if not os.path.isdir(target):
        os.makedirs(target)
    for file_url, fileName in zip(fileUrls, fileNames):
        try:
            logging.info(fileName.strip())
            response = requests.get(file_url, stream="TRUE")
            downloadFile = target + '/' + fileName.strip() # 放置資料夾路徑 + 檔名
            logging.info(downloadFile)
            with open(downloadFile,'wb') as file:
                for data in response.iter_content():
                    file.write(data)
        except:
            logging.error("爬取檔案失敗")
            logging.error("失敗連結：" + file_url)
            logging.error('title:' + title)

# %%
def dataProcess_Detail(soup, row):
    urlmoj = 'https://law.moj.gov.tw' # linkto 全國法規資料庫
    urlGazette = 'http://gazette.nat.gov.tw' # linkto 行政院公報資訊網
    fileUrlRoot_moj = 'https://law.moj.gov.tw/news/'
    title = row['標題']
    link = row['內文連結']
    result = dict()
    if link.find(urlmoj) >= 0:
        result['content'] = [e.text for e in soup.select('pre')][0]
        result['fileNames'] = [e.text for e in soup.select('#Content a')][3:]
        result['fileUrls'] = [fileUrlRoot_moj + e.get('href') for e in soup.select('#Content a')][3:]
        result['serno'] = ''
        result['issue_date'] = [e.text for e in soup.select('#lbDate')][0]
    elif link.find(urlGazette) >= 0:
        result['fileUrls'] = [urlGazette + e.get('src') for e in soup.select('.embed-responsive-item')]
        result['fileNames'] = [title + '.pdf'for i in range(len(result['fileUrls']))]
        result['content'] = ''
        result['serno'] = soup.select('div.Item section.Block p span')[2].text
        result['issue_date'] = soup.select('div.Item section.Block p span')[1].text
    else:
        log.info('出現新的連結網站，需要新增爬蟲程式')
    return result

# %%
def parsingDetail(df, finalPath): 
    df2 = pd.DataFrame(columns = ["標題", "全文內容", "附件", "發文字號", "發文日期", "相關法條"])
    for index, row in df.iterrows():
        try:
            title = row['標題']
            link = row['內文連結']
            logging.info(title)
            soup = request2soup(link)
            result = dataProcess_Detail(soup, row)
            fileNames = result['fileNames'] 
            if len(fileNames) != 0:
                downloadFile(finalPath, title, result['fileUrls'], fileNames)
            d = {'標題': title, '全文內容': result['content'], '附件':','.join(fileNames), '發文字號':result['serno'], 
                 '發文日期':result['issue_date'], '相關法條':''}
            df2= df2.append(pd.DataFrame(data=d, index=[0]))
        except:
            logging.error("爬取內文失敗\n")
            logging.error("失敗連結：" + link+ '\n')
            traceback.print_exc()
    return df2

# %%
def outputCsv(df, fileName, path):
    # 若目錄不存在，建立目錄
    if not os.path.isdir(path):
        os.mkdir(path)
    df.to_csv(path + "/" + fileName + ".csv", index = False, encoding = "utf_8_sig")

# %%
def compareTo(strDate, endDate):
    if int(re.split(r'(/|-|\.)', strDate)[0]) < 1911:
        strDate = datetime.datetime.strptime(str(int(re.sub(r'(/|-|\.)', '', strDate)) + 19110000), "%Y%m%d").strftime("%Y-%m-%d")
    if int(re.split(r'(/|-|\.)', endDate)[0]) < 1911:
        endDate = datetime.datetime.strptime(str(int(re.sub(r'(/|-|\.)', '', endDate)) + 19110000), "%Y%m%d").strftime("%Y-%m-%d")
    try:
        strDate = datetime.datetime.strptime(strDate, "%Y-%m-%d")
        endDate = datetime.datetime.strptime(endDate, "%Y-%m-%d")

    except:
        logging.error('compareTo(strDate, endDate):')
        logging.error("日期格式錯誤：strDate = %s, endDate = %s" %(strDate, endDate))
        return
    if strDate < endDate:
        return 1
    elif strDate == endDate:
        return 0
    else:
        return -1

# %%
def dataProcess_Title(soup, strDate):
    result = dict()
    titles_result = []
    dates = []
    links = []
    nowPage = 1
    end = False
    while True:
        try:
            if nowPage > 1:
                url = 'https://www.moj.gov.tw/lp-22-001-' + str(nowPage) +'-20.html'
                soup = request2soup(url)
            titles = [str(e.get('title')) for e in soup.select('.list a')]
            if titles == []:
                break
            for index in range(len(titles)):
                try:
                    title = titles[index]
                    date = soup.select('td[data-title="張貼日"]')[index].text.strip()
                    if compareTo(date, strDate) > 0:
                        end = True
                        break
                    link = soup.select('.list a')[index].get('href')
                    titles_result.append(title)
                    dates.append(date)
                    links.append(link)
                except:
                    logging.error("爬取第 %s 頁第 %s 筆主旨發生錯誤" %(nowPage, index + 1))
            if end == True:
                break
            nowPage += 1
        except:
            logging.error("爬取第 %s 頁主旨發生錯誤" %(nowPage))
            traceback.print_exc()
        
    result['titles_result'] = titles_result
    result['dates'] = dates
    result['links'] = links
    result['nowPage'] = nowPage
    result['index'] = index + 1
    return result

# %%
def parsingTitle(soup, checkRange):
    
    try:
        # 取得上次爬網結果
        if os.path.isfile(lastResultPath):
            lastResult = pd.read_csv(lastResultPath)
        else:
            lastResult = pd.DataFrame()
            
        endDate = datetime.date.today()
        strDate = (endDate - datetime.timedelta(days = checkRange)).isoformat()
        df = pd.DataFrame(columns=['爬網日期','發文日期','標題','內文連結'])
        
         # 資料處理
        result = dataProcess_Title(soup, strDate)   
        
        d = {'爬網日期':endDate,'發文日期': result['dates'], '標題': result['titles_result'], '內文連結': result['links']}
        df = df.append(pd.DataFrame(data=d))
        # 若與上次發文日期和標題相同，則跳至下一筆
        if not lastResult.empty:
            for index, row in df.iterrows():
                if (row['發文日期'] in list(lastResult['發文日期'])) and (row['標題'] in list(lastResult['標題'])):
                    df.drop(index, inplace = True)

        if len(df) == 0:
            logging.critical("%s 至 %s 間無資料更新" %(strDate, endDate))
        else:
            df.index = [i for i in range(df.shape[0])] # reset
            outputCsv(df, "lastResult", "./CrawlList")

    except:
        logging.error("爬取主旨列表失敗")
        traceback.print_exc()
    
    return df

# %%
def request2soup(url):
    res = requests.get(url)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text,'html.parser',from_encoding='utf-8')
    return soup

# %%
def main(url, checkRange = 10):
    
    logging.critical("\n")
    logging.critical("爬網開始......")
    logging.critical("目標網址：" + url)
    
    strTime = datetime.datetime.now()
    logging.critical("開始時間：" + strTime.strftime("%Y/%m/%d %H:%M:%S"))
    
    try:
        soup = request2soup(url)
        df_1 = parsingTitle(soup, checkRange)
        if len(df_1) == 0:
            return
        outputCsv(df_1, "第一層結果", FinalPath)

        df_2 = parsingDetail(df_1, FinalPath)
        outputCsv(df_2, "第二層結果", FinalPath)
    except:
        logging.error("執行爬網作業失敗")
        traceback.print_exc()
    
    endTime = datetime.datetime.now()
    logging.critical("結束時間：" + endTime.strftime("%Y/%m/%d %H:%M:%S"))
    logging.critical("執行時間：" + str((endTime - strTime).seconds) + " 秒")
    logging.critical("輸出筆數：" + str(len(df_1)) + " 筆")
    logging.critical("爬網結束......")

# %%
if __name__ == "__main__":
    url = 'https://www.moj.gov.tw/lp-22-001-1-20.html'
    main(url)
# Out:
# 2018-12-13 18:09:28,902 - <ipython-input-21-af5d5cf396fc>[line:3] - CRITICAL:
#
# 2018-12-13 18:09:28,910 - <ipython-input-21-af5d5cf396fc>[line:4] - CRITICAL: 爬網開始......
# 2018-12-13 18:09:28,911 - <ipython-input-21-af5d5cf396fc>[line:5] - CRITICAL: 目標網址：https://www.moj.gov.tw/lp-22-001-1-20.html
# 2018-12-13 18:09:28,912 - <ipython-input-21-af5d5cf396fc>[line:8] - CRITICAL: 開始時間：2018/12/13 18:09:28
# C:\Users\Administrator\Anaconda3\lib\site-packages\bs4\__init__.py:179: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# 2018-12-13 18:09:30,643 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院農業委員會公告：修正「福建省金門縣偶蹄類動物及其產品禁止輸往臺灣本島及其他離島」第3點規定，並修正名稱為「金門地區偶蹄類動物及其產品禁止輸往臺灣本島及其他離島」，自即日生效
# 2018-12-13 18:09:33,852 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院農業委員會公告：修正「福建省金門縣偶蹄類動物及其產品禁止輸往臺灣本島及其他離島」第3點規定，並修正名稱為「金門地區偶蹄類動物及其產品禁止輸往臺灣本島及其他離島」，自即日生效.pdf
# 2018-12-13 18:09:33,943 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會公告：修正「福建省金門縣偶蹄類動/《法規命令》行政院農業委員會公告：修正「福建省金門縣偶蹄類動物及其產品禁止輸往臺灣本島及其他離島」第3點規定，並修正名稱為「金門地區偶蹄類動物及其產品禁止輸往臺灣本島及其他離島」，自即日生效.pdf
# 2018-12-13 18:09:35,060 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：訂定「水中全滅草檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W643.51A）」，自108年3月15日生效
# 2018-12-13 18:09:39,457 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：訂定「水中全滅草檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W643.51A）」，自108年3月15日生效.pdf
# 2018-12-13 18:09:39,559 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：訂定「水中全滅草檢測方法－/《法規命令》行政院環境保護署公告：訂定「水中全滅草檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W643.51A）」，自108年3月15日生效.pdf
# 2018-12-13 18:09:46,073 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：廢止「水中全滅草檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W643.50A）」，自108年3月15日生效
# 2018-12-13 18:09:48,199 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：廢止「水中全滅草檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W643.50A）」，自108年3月15日生效.pdf
# 2018-12-13 18:09:48,372 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：廢止「水中全滅草檢測方法－/《法規命令》行政院環境保護署公告：廢止「水中全滅草檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W643.50A）」，自108年3月15日生效.pdf
# 2018-12-13 18:09:49,146 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》法務部令：修正「法務部處務規程」
# 2018-12-13 18:09:49,315 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:09:49,457 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》法務部令：修正「法務部處務規程」/總說明.pdf
# 2018-12-13 18:09:49,789 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:09:50,133 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》法務部令：修正「法務部處務規程」/對照表.pdf
# 2018-12-13 18:09:50,672 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》法務部令：修正「法醫師申請執行鑑定業務審查辦法」
# 2018-12-13 18:09:51,054 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:09:51,411 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》法務部令：修正「法醫師申請執行鑑定業務審查辦法」/總說明.pdf
# 2018-12-13 18:09:51,683 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:09:52,092 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》法務部令：修正「法醫師申請執行鑑定業務審查辦法」/對照表.pdf
# 2018-12-13 18:09:52,382 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：訂定「戴奧辛及呋喃檢測方法－同位素標幟稀釋氣相層析／串聯式質譜儀法（NIEA M805.01B）」，自108年3月15日生效
# 2018-12-13 18:09:54,597 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：訂定「戴奧辛及呋喃檢測方法－同位素標幟稀釋氣相層析／串聯式質譜儀法（NIEA M805.01B）」，自108年3月15日生效.pdf
# 2018-12-13 18:09:54,713 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：訂定「戴奧辛及呋喃檢測方法/《法規命令》行政院環境保護署公告：訂定「戴奧辛及呋喃檢測方法－同位素標幟稀釋氣相層析／串聯式質譜儀法（NIEA M805.01B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:14,800 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》財政部令：依據「貨物稅條例」第17條第2項訂定「飲料品容器成本通常標準表」，自即日生效
# 2018-12-13 18:10:16,941 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》財政部令：依據「貨物稅條例」第17條第2項訂定「飲料品容器成本通常標準表」，自即日生效.pdf
# 2018-12-13 18:10:17,113 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》財政部令：依據「貨物稅條例」第17條第2項訂定「/《法規命令》財政部令：依據「貨物稅條例」第17條第2項訂定「飲料品容器成本通常標準表」，自即日生效.pdf
# 2018-12-13 18:10:24,837 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：訂定「事業放流水採樣方法（NIEA W109.52B）」，自108年3月15日生效
# 2018-12-13 18:10:35,086 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：訂定「事業放流水採樣方法（NIEA W109.52B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:35,214 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：訂定「事業放流水採樣方法（/《法規命令》行政院環境保護署公告：訂定「事業放流水採樣方法（NIEA W109.52B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:45,811 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：廢止「戴奧辛及呋喃檢測方法－同位素標幟稀釋氣相層析／串聯式質譜儀法（NIEA M805.00B）」，自108年3月15日生效
# 2018-12-13 18:10:47,957 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：廢止「戴奧辛及呋喃檢測方法－同位素標幟稀釋氣相層析／串聯式質譜儀法（NIEA M805.00B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:48,059 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：廢止「戴奧辛及呋喃檢測方法/《法規命令》行政院環境保護署公告：廢止「戴奧辛及呋喃檢測方法－同位素標幟稀釋氣相層析／串聯式質譜儀法（NIEA M805.00B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:48,937 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》衛生福利部中央健康保險署令：修正「全民健康保險保險人資訊整合應用服務收費標準」
# 2018-12-13 18:10:49,110 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:10:49,259 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部中央健康保險署令：修正「全民健康保險保/總說明.pdf
# 2018-12-13 18:10:49,822 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:10:50,005 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部中央健康保險署令：修正「全民健康保險保/對照表.pdf
# 2018-12-13 18:10:50,604 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：廢止「事業放流水採樣方法（NIEA W109.51B）」，自108年3月15日生效
# 2018-12-13 18:10:54,902 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：廢止「事業放流水採樣方法（NIEA W109.51B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:55,040 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：廢止「事業放流水採樣方法（/《法規命令》行政院環境保護署公告：廢止「事業放流水採樣方法（NIEA W109.51B）」，自108年3月15日生效.pdf
# 2018-12-13 18:10:55,848 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》經濟部令：修正「產業園區閒置土地認定與輔導使用及強制拍賣辦法」
# 2018-12-13 18:10:56,101 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:10:56,349 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：修正「產業園區閒置土地認定與輔導使用及/總說明.pdf
# 2018-12-13 18:10:56,915 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:10:57,084 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：修正「產業園區閒置土地認定與輔導使用及/對照表.pdf
# 2018-12-13 18:10:57,530 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》經濟部令：修正「商業會計處理準則」
# 2018-12-13 18:10:57,715 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:10:57,914 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：修正「商業會計處理準則」/總說明.pdf
# 2018-12-13 18:10:58,217 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:10:58,398 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：修正「商業會計處理準則」/對照表.pdf
# 2018-12-13 18:10:59,185 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院、監察院公告：公告「公職人員利益衝突迴避法第十四條第一項但書第六款所稱一定金額」，自107年12月13日生效
# 2018-12-13 18:11:06,463 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院、監察院公告：公告「公職人員利益衝突迴避法第十四條第一項但書第六款所稱一定金額」，自107年12月13日生效.pdf
# 2018-12-13 18:11:06,573 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院、監察院公告：公告「公職人員利益衝突迴避法/《法規命令》行政院、監察院公告：公告「公職人員利益衝突迴避法第十四條第一項但書第六款所稱一定金額」，自107年12月13日生效.pdf
# 2018-12-13 18:11:07,415 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》經濟部標準檢驗局公告：訂定「應施檢驗熱軋H型鋼商品之相關檢驗規定」，自即日生效
# 2018-12-13 18:11:11,640 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》經濟部標準檢驗局公告：訂定「應施檢驗熱軋H型鋼商品之相關檢驗規定」，自即日生效.pdf
# 2018-12-13 18:11:11,788 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部標準檢驗局公告：訂定「應施檢驗熱軋H型鋼商/《法規命令》經濟部標準檢驗局公告：訂定「應施檢驗熱軋H型鋼商品之相關檢驗規定」，自即日生效.pdf
# 2018-12-13 18:11:13,355 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化博物館規費收費標準」
# 2018-12-13 18:11:13,572 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表一  展示廳參觀票價.odt
# 2018-12-13 18:11:13,715 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化/附表一  展示廳參觀票價.odt
# 2018-12-13 18:11:13,824 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表五  卑南遺址公園展示廳參觀票價.odt
# 2018-12-13 18:11:13,991 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化/附表五  卑南遺址公園展示廳參觀票價.odt
# 2018-12-13 18:11:14,079 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表五之一  南科考古館展示廳參觀票價.odt
# 2018-12-13 18:11:14,263 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化/附表五之一  南科考古館展示廳參觀票價.odt
# 2018-12-13 18:11:14,356 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表六  卑南遺址公園場地設備管理規費收費標準.odt
# 2018-12-13 18:11:14,526 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化/附表六  卑南遺址公園場地設備管理規費收費標準.odt
# 2018-12-13 18:11:14,648 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:14,798 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化/總說明.pdf
# 2018-12-13 18:11:15,068 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:15,235 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國立臺灣史前文化博物館令：修正「國立臺灣史前文化/對照表.pdf
# 2018-12-13 18:11:15,678 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》交通部令：修正「危險物品空運管理辦法」
# 2018-12-13 18:11:15,857 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附件二危險物品事件報告.odt
# 2018-12-13 18:11:16,054 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》交通部令：修正「危險物品空運管理辦法」/附件二危險物品事件報告.odt
# 2018-12-13 18:11:16,176 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:16,328 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》交通部令：修正「危險物品空運管理辦法」/總說明.pdf
# 2018-12-13 18:11:17,069 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:17,233 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》交通部令：修正「危險物品空運管理辦法」/對照表.pdf
# 2018-12-13 18:11:18,097 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院令：修正「科學工業園區管理局作業基金收支保管及運用辦法」名稱為「科學園區管理局作業基金收支保管及運用辦法」並修正部分條文
# 2018-12-13 18:11:18,295 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:18,465 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院令：修正「科學工業園區管理局作業基金收支保/總說明.pdf
# 2018-12-13 18:11:18,839 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:19,053 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院令：修正「科學工業園區管理局作業基金收支保/對照表.pdf
# 2018-12-13 18:11:20,053 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院農業委員會屏東農業生物技術園區籌備處令：訂定「行政院農業委員會屏東農業生物技術園區籌備處建築執照規費收費標準」
# 2018-12-13 18:11:20,227 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:20,373 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會屏東農業生物技術園區籌備處令：訂/總說明.pdf
# 2018-12-13 18:11:20,659 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:20,837 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會屏東農業生物技術園區籌備處令：訂/對照表.pdf
# 2018-12-13 18:11:21,168 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》內政部令：修正「內政部移民署編制表」
# 2018-12-13 18:11:21,415 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 內政部移民署編制表.pdf
# 2018-12-13 18:11:21,591 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「內政部移民署編制表」/內政部移民署編制表.pdf
# 2018-12-13 18:11:22,147 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:22,314 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「內政部移民署編制表」/總說明.pdf
# 2018-12-13 18:11:22,570 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:22,719 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「內政部移民署編制表」/對照表.pdf
# 2018-12-13 18:11:23,409 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》衛生福利部令：修正「全民健康保險投保金額分級表」，自108年1月1日生效
# 2018-12-13 18:11:27,637 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》衛生福利部令：修正「全民健康保險投保金額分級表」，自108年1月1日生效.pdf
# 2018-12-13 18:11:27,743 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部令：修正「全民健康保險投保金額分級表」/《法規命令》衛生福利部令：修正「全民健康保險投保金額分級表」，自108年1月1日生效.pdf
# 2018-12-13 18:11:34,028 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》衛生福利部令：訂定「獎勵兒童及少年未來教育與發展帳戶開戶人存款辦法」
# 2018-12-13 18:11:34,196 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:34,353 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部令：訂定「獎勵兒童及少年未來教育與發展/總說明.pdf
# 2018-12-13 18:11:34,684 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:34,837 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部令：訂定「獎勵兒童及少年未來教育與發展/對照表.pdf
# 2018-12-13 18:11:35,494 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》衛生福利部令：訂定「政府接受捐贈用於兒童及少年未來教育與發展帳戶分配辦法」
# 2018-12-13 18:11:35,690 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:35,860 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部令：訂定「政府接受捐贈用於兒童及少年未/總說明.pdf
# 2018-12-13 18:11:36,507 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:36,652 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》衛生福利部令：訂定「政府接受捐贈用於兒童及少年未/對照表.pdf
# 2018-12-13 18:11:37,329 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部／行政院環境保護署令：修正「科學工業園區廢棄物共同清除處理機構管理辦法」名稱為「科學園區廢棄物共同清除處理機構管理辦法」並修正第1條、第2條條文
# 2018-12-13 18:11:37,522 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:37,704 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部／行政院環境保護署令：修正「科學工業園區廢/總說明.pdf
# 2018-12-13 18:11:38,429 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:38,644 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部／行政院環境保護署令：修正「科學工業園區廢/對照表.pdf
# 2018-12-13 18:11:39,327 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》國軍退除役官兵輔導委員會令：廢止「行政院國軍退除役官兵輔導委員會榮民工程事業管理處組織規程」
# 2018-12-13 18:11:39,522 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部令：修正「科學工業園區設置管理條例施行細則」名稱為「科學園區設置管理條例施行細則」並修正全文
# 2018-12-13 18:11:39,714 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:39,874 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科學工業園區設置管理條例施行細則/總說明.pdf
# 2018-12-13 18:11:40,704 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:40,916 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科學工業園區設置管理條例施行細則/對照表.pdf
# 2018-12-13 18:11:42,180 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》經濟部公告：訂定「國營事業編列研究發展支出占總預算比例」，自即日生效
# 2018-12-13 18:11:46,367 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》經濟部公告：訂定「國營事業編列研究發展支出占總預算比例」，自即日生效.pdf
# 2018-12-13 18:11:46,526 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部公告：訂定「國營事業編列研究發展支出占總預/《法規命令》經濟部公告：訂定「國營事業編列研究發展支出占總預算比例」，自即日生效.pdf
# 2018-12-13 18:11:47,885 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部令：修正「科技部新竹科學工業園區管理局消防隊設置辦法」名稱為「科技部新竹科學園區管理局消防隊設置辦法」並修正第1條條文
# 2018-12-13 18:11:48,097 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:48,399 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科技部新竹科學工業園區管理局消防/總說明.pdf
# 2018-12-13 18:11:49,185 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:49,336 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科技部新竹科學工業園區管理局消防/對照表.pdf
# 2018-12-13 18:11:50,234 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》經濟部令：訂定「電子遊戲機及電子遊戲場管理辦法」
# 2018-12-13 18:11:50,416 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附件一  電子遊戲機評鑑申請表.odt
# 2018-12-13 18:11:50,630 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：訂定「電子遊戲機及電子遊戲場管理辦法」/附件一  電子遊戲機評鑑申請表.odt
# 2018-12-13 18:11:50,766 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附件二  電子遊戲機說明書.odt
# 2018-12-13 18:11:50,933 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：訂定「電子遊戲機及電子遊戲場管理辦法」/附件二  電子遊戲機說明書.odt
# 2018-12-13 18:11:51,059 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:51,219 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：訂定「電子遊戲機及電子遊戲場管理辦法」/總說明.pdf
# 2018-12-13 18:11:51,940 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:52,135 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》經濟部令：訂定「電子遊戲機及電子遊戲場管理辦法」/對照表.pdf
# 2018-12-13 18:11:52,935 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部令：修正「科學工業園區管理費收取辦法」名稱為「科學園區管理費收取辦法」並修正全文
# 2018-12-13 18:11:53,150 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表一 園區事業管理費基本費浮動費率表.pdf
# 2018-12-13 18:11:53,332 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科學工業園區管理費收取辦法」名稱/附表一 園區事業管理費基本費浮動費率表.pdf
# 2018-12-13 18:11:53,768 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表二 科學園區內其他機構（不含園區事業及金融機構）管理費收費一覽表.pdf
# 2018-12-13 18:11:53,922 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科學工業園區管理費收取辦法」名稱/附表二 科學園區內其他機構（不含園區事業及金融機構）管理費收費一覽表.pdf
# 2018-12-13 18:11:54,338 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:54,476 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科學工業園區管理費收取辦法」名稱/總說明.pdf
# 2018-12-13 18:11:54,872 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:55,071 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科學工業園區管理費收取辦法」名稱/對照表.pdf
# 2018-12-13 18:11:56,072 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部令：修正「科技部新竹科學工業園區管理局清潔隊設置辦法」名稱為「科技部新竹科學園區管理局清潔隊設置辦法」並修正第1條條文
# 2018-12-13 18:11:56,242 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:56,416 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科技部新竹科學工業園區管理局清潔/總說明.pdf
# 2018-12-13 18:11:56,929 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:57,077 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「科技部新竹科學工業園區管理局清潔/對照表.pdf
# 2018-12-13 18:11:57,695 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法律》修正工業團體法條文
# 2018-12-13 18:11:57,858 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》內政部令：修正「臺灣地區無戶籍國民申請入國居留定居許可辦法」
# 2018-12-13 18:11:58,666 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:58,930 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「臺灣地區無戶籍國民申請入國居留定/總說明.pdf
# 2018-12-13 18:11:59,196 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:11:59,334 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「臺灣地區無戶籍國民申請入國居留定/對照表.pdf
# 2018-12-13 18:11:59,633 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部／經濟部令：訂定「科技部科學園區水電輔導管制辦法」
# 2018-12-13 18:11:59,813 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:11:59,963 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部／經濟部令：訂定「科技部科學園區水電輔導管/總說明.pdf
# 2018-12-13 18:12:00,650 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:00,838 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部／經濟部令：訂定「科技部科學園區水電輔導管/對照表.pdf
# 2018-12-13 18:12:01,564 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》內政部令：修正「外國人停留居留及永久居留辦法」
# 2018-12-13 18:12:01,730 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:01,896 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「外國人停留居留及永久居留辦法」/總說明.pdf
# 2018-12-13 18:12:02,175 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:02,411 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「外國人停留居留及永久居留辦法」/對照表.pdf
# 2018-12-13 18:12:02,740 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院農業委員會令： 修正「農會漁會信用部淨值占風險性資產比率管理辦法」
# 2018-12-13 18:12:02,923 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表一  信用部淨值占風險性資產比率計算表.odt
# 2018-12-13 18:12:03,038 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令： 修正「農會漁會信用部淨值占/附表一  信用部淨值占風險性資產比率計算表.odt
# 2018-12-13 18:12:03,117 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:03,331 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令： 修正「農會漁會信用部淨值占/總說明.pdf
# 2018-12-13 18:12:04,009 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:04,165 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令： 修正「農會漁會信用部淨值占/對照表.pdf
# 2018-12-13 18:12:04,898 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法律》制定財團法人原住民族語言研究發展基金會設置條例
# 2018-12-13 18:12:05,052 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》國家發展委員會令：修正「國家發展委員會編制表」
# 2018-12-13 18:12:05,235 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 國家發展委員會編制表.pdf
# 2018-12-13 18:12:05,473 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國家發展委員會令：修正「國家發展委員會編制表」/國家發展委員會編制表.pdf
# 2018-12-13 18:12:08,158 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》國家發展委員會令：修正「國家發展委員會檔案管理局編制表」
# 2018-12-13 18:12:08,338 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 國家發展委員會檔案管理局編制表.pdf
# 2018-12-13 18:12:08,525 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》國家發展委員會令：修正「國家發展委員會檔案管理局/國家發展委員會檔案管理局編制表.pdf
# 2018-12-13 18:12:10,903 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法律》增訂、刪除並修正郵政法條文
# 2018-12-13 18:12:11,077 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》內政部令：修正「風災震災火災爆炸火山災害潛勢資料公開辦法」
# 2018-12-13 18:12:11,267 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:11,448 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「風災震災火災爆炸火山災害潛勢資料/總說明.pdf
# 2018-12-13 18:12:11,838 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:12,007 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》內政部令：修正「風災震災火災爆炸火山災害潛勢資料/對照表.pdf
# 2018-12-13 18:12:12,425 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法律》修正總統副總統選舉罷免法條文
# 2018-12-13 18:12:12,604 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法律》制定勞動事件法
# 2018-12-13 18:12:12,832 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行事項」第4點、第7點、第8點規定，自即日生效
# 2018-12-13 18:12:18,233 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行事項」第4點、第7點、第8點規定，自即日生效.pdf
# 2018-12-13 18:12:18,426 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行/《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行事項」第4點、第7點、第8點規定，自即日生效.pdf
# 2018-12-13 18:12:25,437 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W783.51B）」，自108年3月15日生效
# 2018-12-13 18:12:28,678 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W783.51B）」，自108年3月15日生效.pdf
# 2018-12-13 18:12:28,996 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法/《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W783.51B）」，自108年3月15日生效.pdf
# 2018-12-13 18:12:36,594 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」
# 2018-12-13 18:12:36,836 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表一  公私有林林產物採運許可證.pdf
# 2018-12-13 18:12:37,087 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表一  公私有林林產物採運許可證.pdf
# 2018-12-13 18:12:37,834 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表二  甲種林產物放行查驗明細表.pdf
# 2018-12-13 18:12:38,053 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表二  甲種林產物放行查驗明細表.pdf
# 2018-12-13 18:12:38,938 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表三  乙種林產物放行查驗明細表.pdf
# 2018-12-13 18:12:39,811 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表三  乙種林產物放行查驗明細表.pdf
# 2018-12-13 18:12:41,316 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表四  甲種林產物搬運單.pdf
# 2018-12-13 18:12:41,538 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表四  甲種林產物搬運單.pdf
# 2018-12-13 18:12:42,367 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表五  乙種林產物搬運單.pdf
# 2018-12-13 18:12:42,557 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表五  乙種林產物搬運單.pdf
# 2018-12-13 18:12:43,351 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表六  直營林產物搬運單.pdf
# 2018-12-13 18:12:43,531 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表六  直營林產物搬運單.pdf
# 2018-12-13 18:12:44,329 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:44,508 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/總說明.pdf
# 2018-12-13 18:12:45,031 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:45,421 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/對照表.pdf
# 2018-12-13 18:12:51,223 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵檢器法（NIEA W783.50B）」，自108年3月15日生效
# 2018-12-13 18:12:53,366 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵檢器法（NIEA W783.50B）」，自108年3月15日生效.pdf
# 2018-12-13 18:12:53,470 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法/《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵檢器法（NIEA W783.50B）」，自108年3月15日生效.pdf
# 2018-12-13 18:12:54,266 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》法務部令：修正「法醫師繼續教育實施辦法」
# 2018-12-13 18:12:54,448 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:54,606 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》法務部令：修正「法醫師繼續教育實施辦法」/總說明.pdf
# 2018-12-13 18:12:54,907 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:55,050 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》法務部令：修正「法醫師繼續教育實施辦法」/對照表.pdf
# 2018-12-13 18:12:55,389 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部令：修正「民間園區併入科學工業園區設置管理辦法」名稱為「民間園區併入科學園區設置管理辦法」並修正全文
# 2018-12-13 18:12:55,557 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:55,724 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「民間園區併入科學工業園區設置管理/總說明.pdf
# 2018-12-13 18:12:56,456 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:56,614 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：修正「民間園區併入科學工業園區設置管理/對照表.pdf
# 2018-12-13 18:12:57,478 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相關事業管理辦法」名稱為「保險業投資保險相關事業管理辦法」並修正全文
# 2018-12-13 18:12:57,639 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 附表：保險業投資保險相關事業申請表.pdf
# 2018-12-13 18:12:57,803 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相/附表：保險業投資保險相關事業申請表.pdf
# 2018-12-13 18:12:58,168 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:12:58,341 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相/總說明.pdf
# 2018-12-13 18:12:58,766 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:12:58,974 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相/對照表.pdf
# 2018-12-13 18:13:00,487 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》科技部令：訂定「科學園區公共空間維護管理辦法」
# 2018-12-13 18:13:00,699 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 總說明.pdf
# 2018-12-13 18:13:00,884 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：訂定「科學園區公共空間維護管理辦法」/總說明.pdf
# 2018-12-13 18:13:01,666 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 對照表.pdf
# 2018-12-13 18:13:01,899 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》科技部令：訂定「科學園區公共空間維護管理辦法」/對照表.pdf
# 2018-12-13 18:13:02,950 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.72B）」，自108年3月15日生效
# 2018-12-13 18:13:06,099 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.72B）」，自108年3月15日生效.pdf
# 2018-12-13 18:13:06,213 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰/《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.72B）」，自108年3月15日生效.pdf
# 2018-12-13 18:13:18,283 - <ipython-input-15-319a7fa77fc6>[line:6] - INFO: 《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.71B）」，自108年3月15日生效
# 2018-12-13 18:13:21,609 - <ipython-input-13-1f7a555caa04>[line:8] - INFO: 《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.71B）」，自108年3月15日生效.pdf
# 2018-12-13 18:13:21,729 - <ipython-input-13-1f7a555caa04>[line:11] - INFO: ./Result/《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰/《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.71B）」，自108年3月15日生效.pdf
# 2018-12-13 18:13:22,749 - <ipython-input-21-af5d5cf396fc>[line:24] - CRITICAL: 結束時間：2018/12/13 18:13:22
# 2018-12-13 18:13:22,751 - <ipython-input-21-af5d5cf396fc>[line:25] - CRITICAL: 執行時間：233 秒
# 2018-12-13 18:13:22,754 - <ipython-input-21-af5d5cf396fc>[line:26] - CRITICAL: 輸出筆數：53 筆
# 2018-12-13 18:13:22,758 - <ipython-input-21-af5d5cf396fc>[line:27] - CRITICAL: 爬網結束......
