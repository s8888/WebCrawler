# %% [raw]
# '''
# Project Name: bankingGov project
# Crawl Cycle: Daily
# Main Website: https://www.moj.gov.tw/lp-22-001-1-20.html
# author      : 林德昌
# date        : 2018/10/16
# description : 抓取法務部每天發布的最新消息
# '''

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import header
import logging
import re
import sys
import datetime
import pandas as pd
import traceback # 印log
import os
TempPath = "./Temp"  # browser file
FinalPath = "./Result" # project file

# %%
def downloadFile(finalPath, title, fileUrls, fileNames): # for download pdf or doc
    target = finalPath + '/' + title[:30].strip()
    # 若目錄不存在，建立目錄
    if not os.path.isdir(target):
        os.makedirs(target)
    i = 0
    for file_url, fileName in zip(fileUrls, fileNames):
        try:
            print(fileName.strip())
            response = requests.get(file_url, stream="TRUE")
            downloadFile = target + '/' + fileName.strip() # 放置資料夾路徑 + 檔名
            print(downloadFile)
            with open(downloadFile,'wb') as file:
                for data in response.iter_content():
                    file.write(data)
        except:
            print("爬取檔案失敗")
            print("失敗連結：" + file_url)
            print('title:' + title)
            logging.error("爬取檔案失敗")
            logging.error("失敗連結：" + file_url)
        i += 1

# %%
def dataProcess_Detail(soup, row, urlmoj, urlGazette, fileUrlRoot_moj):
    title = row['title']
    link = row['link']
    date = row['date']
    result = dict()
    if link.find(urlmoj) >= 0:
        result['content'] = [e.text for e in soup.select('pre')][0]
        result['fileNames'] = [e.text for e in soup.select('#Content a')][3:]
        result['fileUrls'] = [fileUrlRoot_moj + e.get('href') for e in soup.select('#Content a')][3:]
        result['serno'] = ''
    elif link.find(urlGazette) >= 0:
        result['fileUrls'] = [urlGazette + e.get('src') for e in soup.select('.embed-responsive-item')]
        result['fileNames'] = [title + '.pdf'for i in range(len(result['fileUrls']))]
        result['content'] = ''
        result['serno'] = soup.select('div.Item section.Block p span')[2].text
    else:
        print('new Web Type!!')
    return result

# %%
def parsingDetail(df, finalPath): 
    urlmoj = 'https://law.moj.gov.tw' # linkto 全國法規資料庫
    urlGazette = 'http://gazette.nat.gov.tw' # linkto 行政院公報資訊網
    fileUrlRoot_moj = 'https://law.moj.gov.tw/news/'
    df2 = pd.DataFrame(columns = ["標題", "全文內容", "附件", "發文字號", "發文日期", "相關法條"])
    for index, row in df.iterrows():
        title = row['title']
        link = row['link']
        date = row['date']
        try:
            soup = request2soup(link)
            result = dataProcess_Detail(soup, row, urlmoj, urlGazette, fileUrlRoot_moj)
        except:
            print("爬取內文失敗\n")
            print("失敗連結：" + link + '\n')
            logging.error("爬取內文失敗")
            logging.error("失敗連結：" + link)
            traceback.print_exc()
        fileNames = result['fileNames'] 
        if len(fileNames) != 0:
            downloadFile(finalPath, title, result['fileUrls'], fileNames)
        d = {'標題': title, '全文內容': result['content'], '附件':','.join(fileNames), '發文字號':result['serno'], 
             '發文日期':date, '相關法條':''}
        df2= df2.append(pd.DataFrame(data=d, index=[0]))
    return df2

# %%
def outputCsv(df, fileName, path):
    # 若目錄不存在，建立目錄
    if not os.path.isdir(path):
        os.mkdir(path)
    df.to_csv(path + "/" + fileName + ".csv", index = False, encoding = "utf_8_sig")

# %%
def compareTo(strDate, endDate):
    if int(re.split(r'(/|-|\.)', strDate)[0]) < 1911:
        strDate = datetime.datetime.strptime(str(int(re.sub(r'(/|-|\.)', '', strDate)) + 19110000), "%Y%m%d").strftime("%Y-%m-%d")
    if int(re.split(r'(/|-|\.)', endDate)[0]) < 1911:
        endDate = datetime.datetime.strptime(str(int(re.sub(r'(/|-|\.)', '', endDate)) + 19110000), "%Y%m%d").strftime("%Y-%m-%d")
    try:
        strDate = datetime.datetime.strptime(strDate, "%Y-%m-%d")
        endDate = datetime.datetime.strptime(endDate, "%Y-%m-%d")

    except:
        print("日期格式錯誤：strDate = %s, endDate = %s" %(strDate, endDate))
        logging.error('compareTo(strDate, endDate):')
        logging.error("日期格式錯誤：strDate = %s, endDate = %s" %(strDate, endDate))
        return
    if strDate < endDate:
        return 1
    elif strDate == endDate:
        return 0
    else:
        return -1

# %%
def dataProcess_Title(soup, strDate):
    result = dict()
    titles_result = []
    dates = []
    links = []
    nowPage = 1
    end = False
    while True:
        try:
            if nowPage > 1:
                url = 'https://www.moj.gov.tw/lp-22-001-' + str(nowPage) +'-20.html'
                soup = request2soup(url)
            titles = [str(e.get('title')) for e in soup.select('.list a')]
            if titles == []:
                break
            for index in range(len(titles)):
                try:
                    title = titles[index]
                    date = soup.select('td[data-title="張貼日"]')[index].text.strip()
                    if compareTo(date, strDate) > 0:
                        end = True
                        break
                    link = soup.select('.list a')[index].get('href')
                    titles_result.append(title)
                    dates.append(date)
                    links.append(link)
                except:
                    print("爬取第 %s 頁第 %s 筆主旨發生錯誤" %(nowPage, index + 1))
                    logging.error("爬取第 %s 頁第 %s 筆主旨發生錯誤" %(nowPage, index + 1))
                    traceback.print_exc()
            if end == True:
                break
            nowPage += 1
        except:
            print("爬取第 %s 頁主旨發生錯誤" %(nowPage))
            logging.error("爬取第 %s 頁主旨發生錯誤" %(nowPage))
            traceback.print_exc()
        
    result['titles_result'] = titles_result
    result['dates'] = dates
    result['links'] = links
    result['nowPage'] = nowPage
    result['index'] = index + 1
    return result

# %%
def parsingTitle(soup, checkRange):
    
    try:
        # 取得上次爬網結果
        lastResultPath = "./CrawlList/lastResult.csv"
        if os.path.isfile(lastResultPath):
            lastResult = pd.read_csv(lastResultPath)
        else:
            lastResult = pd.DataFrame()
            
        endDate = datetime.date.today()
        strDate = (endDate - datetime.timedelta(days = checkRange)).isoformat()
        df = pd.DataFrame(columns=['date','title','link'])
        
         # 資料處理
        result = dataProcess_Title(soup, strDate)   
        
        d = {'date': result['dates'], 'title': result['titles_result'], 'link': result['links']}
        df = df.append(pd.DataFrame(data=d))
        # 若與上次發文日期和標題相同，則跳至下一筆
        if not lastResult.empty:
            for index, row in df.iterrows():
                if (row['date'] in list(lastResult.date)) and (row['title'] in list(lastResult.title)):
                    df.drop(index, inplace = True)

        if len(df) == 0:
            print("%s 至 %s 間無資料更新" %(strDate, endDate))
            logging.critical("%s 至 %s 間無資料更新" %(strDate, endDate))
        else:
            df.index = [i for i in range(df.shape[0])] # reset
            outputCsv(df, "lastResult", "./CrawlList")

    except:
        print("爬取主旨列表失敗")
        logging.error("爬取主旨列表失敗")
        traceback.print_exc()
    
    return df

# %%
def request2soup(url):
    res = requests.get(url)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text,'html.parser',from_encoding='utf-8')
    return soup

# %%
def main(url, checkRange = 10):
    
    logging.critical("\n")
    logging.critical("爬網開始......")
    logging.critical("目標網址：" + url)
    
    strTime = datetime.datetime.now()
    logging.critical("開始時間：" + strTime.strftime("%Y/%m/%d %H:%M:%S"))
    
    try:
        soup = request2soup(url)
        df_1 = parsingTitle(soup, checkRange)
        if len(df_1) == 0:
            return
        outputCsv(df_1, "第一層結果", FinalPath)

        df_2 = parsingDetail(df_1, FinalPath)
        outputCsv(df_2, "第二層結果", FinalPath)
    except:
        print("執行爬網作業失敗")
        logging.error("執行爬網作業失敗")
        traceback.print_exc()
    
    endTime = datetime.datetime.now()
    logging.critical("結束時間：" + endTime.strftime("%Y/%m/%d %H:%M:%S"))
    logging.critical("執行時間：" + str((endTime - strTime).seconds) + " 秒")
    logging.critical("輸出筆數：" + str(len(df_1)) + " 筆")
    logging.critical("爬網結束......")

# %%
if __name__ == "__main__":
    url = 'https://www.moj.gov.tw/lp-22-001-1-20.html'
    main(url)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\bs4\__init__.py:179: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# 《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行事項」第4點、第7點、第8點規定，自即日生效.pdf
# ./Result/《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行/《法規命令》行政院農業委員會公告：修正「鰻魚放養管理及應遵行事項」第4點、第7點、第8點規定，自即日生效.pdf
# 總說明.pdf
# ./Result/《法規命令》法務部令：修正「法醫師繼續教育實施辦法」/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》法務部令：修正「法醫師繼續教育實施辦法」/對照表.pdf
# 附表一  公私有林林產物採運許可證.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表一  公私有林林產物採運許可證.pdf
# 附表二  甲種林產物放行查驗明細表.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表二  甲種林產物放行查驗明細表.pdf
# 附表三  乙種林產物放行查驗明細表.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表三  乙種林產物放行查驗明細表.pdf
# 附表四  甲種林產物搬運單.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表四  甲種林產物搬運單.pdf
# 附表五  乙種林產物搬運單.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表五  乙種林產物搬運單.pdf
# 附表六  直營林產物搬運單.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/附表六  直營林產物搬運單.pdf
# 總說明.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》行政院農業委員會令：修正「林產物伐採查驗規則」/對照表.pdf
# 《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵檢器法（NIEA W783.50B）」，自108年3月15日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法/《法規命令》行政院環境保護署公告：廢止「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵檢器法（NIEA W783.50B）」，自108年3月15日生效.pdf
# 《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W783.51B）」，自108年3月15日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法/《法規命令》行政院環境保護署公告：訂定「水中五氯硝苯檢測方法－氣相層析儀／電子捕捉偵測器法（NIEA W783.51B）」，自108年3月15日生效.pdf
# 總說明.pdf
# ./Result/《法規命令》科技部令：修正「民間園區併入科學工業園區設置管理/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》科技部令：修正「民間園區併入科學工業園區設置管理/對照表.pdf
# 附表：保險業投資保險相關事業申請表.pdf
# ./Result/《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相/附表：保險業投資保險相關事業申請表.pdf
# 總說明.pdf
# ./Result/《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》金融監督管理委員會令：修正「保險業申請投資保險相/對照表.pdf
# 《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.72B）」，自108年3月15日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰/《法規命令》行政院環境保護署公告：訂定「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.72B）」，自108年3月15日生效.pdf
# 總說明.pdf
# ./Result/《法規命令》科技部令：訂定「科學園區公共空間維護管理辦法」/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》科技部令：訂定「科學園區公共空間維護管理辦法」/對照表.pdf
# 《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.71B）」，自108年3月15日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰/《法規命令》行政院環境保護署公告：廢止「加油站油氣管線壓力衰減洩漏檢測方法（NIEA A209.71B）」，自108年3月15日生效.pdf
# 《法規命令》行政院環境保護署公告：修正「行政院環境保護署所主管災害緊急應變警報訊號之種類、內容、樣式、方法及其發布時機」，自即日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：修正「行政院環境保護署所主/《法規命令》行政院環境保護署公告：修正「行政院環境保護署所主管災害緊急應變警報訊號之種類、內容、樣式、方法及其發布時機」，自即日生效.pdf
# 《法規命令》衛生福利部公告：廢止「食品中殘留農藥檢驗方法－殺菌劑二硫代胺基甲酸鹽劑之檢驗（三）」，自即日生效.pdf
# ./Result/《法規命令》衛生福利部公告：廢止「食品中殘留農藥檢驗方法－殺/《法規命令》衛生福利部公告：廢止「食品中殘留農藥檢驗方法－殺菌劑二硫代胺基甲酸鹽劑之檢驗（三）」，自即日生效.pdf
# 《法規命令》衛生福利部公告：修正「食品中動物用藥殘留量檢驗方法－離子型抗球蟲藥之檢驗 」，自108年2月1日生效.pdf
# ./Result/《法規命令》衛生福利部公告：修正「食品中動物用藥殘留量檢驗方/《法規命令》衛生福利部公告：修正「食品中動物用藥殘留量檢驗方法－離子型抗球蟲藥之檢驗 」，自108年2月1日生效.pdf
# 《法規命令》衛生福利部公告：修正「食品中殘留農藥檢驗方法－殺菌劑二硫代胺基甲酸鹽類之檢驗（二）」，自即日生效.pdf
# ./Result/《法規命令》衛生福利部公告：修正「食品中殘留農藥檢驗方法－殺/《法規命令》衛生福利部公告：修正「食品中殘留農藥檢驗方法－殺菌劑二硫代胺基甲酸鹽類之檢驗（二）」，自即日生效.pdf
# 司法院大法官解釋第 770 號.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/司法院大法官解釋第 770 號.pdf
# 湯大法官德宗提出之部分協同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/湯大法官德宗提出之部分協同意見書.pdf
# 蔡大法官明誠提出之部分協同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/蔡大法官明誠提出之部分協同意見書.pdf
# 羅大法官昌發提出之協同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/羅大法官昌發提出之協同意見書.pdf
# 許大法官志雄提出之協同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/許大法官志雄提出之協同意見書.pdf
# 黃大法官瑞明提出之協同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/黃大法官瑞明提出之協同意見書.pdf
# 陳大法官碧玉提出之部分協同部分不同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/陳大法官碧玉提出之部分協同部分不同意見書.pdf
# 黃大法官虹霞提出之部分不同意見書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/黃大法官虹霞提出之部分不同意見書.pdf
# 玉禮實業股份有限公司聲請書.pdf
# ./Result/《大法官解釋》司法院大法官釋字第 770 號/玉禮實業股份有限公司聲請書.pdf
# 《法規命令》衛生福利部公告：廢止「食品中殘留農藥檢驗方法－殺蟲劑因滅汀之檢驗」等8篇檢驗方法，自即日生效.pdf
# ./Result/《法規命令》衛生福利部公告：廢止「食品中殘留農藥檢驗方法－殺/《法規命令》衛生福利部公告：廢止「食品中殘留農藥檢驗方法－殺蟲劑因滅汀之檢驗」等8篇檢驗方法，自即日生效.pdf
# 《法規命令》經濟部公告：訂定「輸配電業線路設置費計算公式」，自即日生效.pdf
# ./Result/《法規命令》經濟部公告：訂定「輸配電業線路設置費計算公式」，/《法規命令》經濟部公告：訂定「輸配電業線路設置費計算公式」，自即日生效.pdf
# 總說明.pdf
# ./Result/《法規命令》國防部令：訂定「陸海空軍軍官士官未服滿最少服役年/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》國防部令：訂定「陸海空軍軍官士官未服滿最少服役年/對照表.pdf
# 總說明.pdf
# ./Result/《法規命令》交通部令：修正「國際機場園區發展條例施行細則」/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》交通部令：修正「國際機場園區發展條例施行細則」/對照表.pdf
# 總說明.pdf
# ./Result/《法規命令》教育部令：修正「教育部補助民間機構訂定運動產業人/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》教育部令：修正「教育部補助民間機構訂定運動產業人/對照表.pdf
# 總說明.pdf
# ./Result/《法規命令》文化部令：修正「水下文化資產審議會組織辦法」/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》文化部令：修正「水下文化資產審議會組織辦法」/對照表.pdf
# 附表一  金融控股公司投資申請案自評表.pdf
# ./Result/《法規命令》金融監督管理委員會令：修正「金融控股公司投資管理/附表一  金融控股公司投資申請案自評表.pdf
# 總說明.pdf
# ./Result/《法規命令》金融監督管理委員會令：修正「金融控股公司投資管理/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》金融監督管理委員會令：修正「金融控股公司投資管理/對照表.pdf
# 總說明.pdf
# ./Result/《法規命令》教育部令：訂定「私立兒童課後照顧服務中心個人資料/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》教育部令：訂定「私立兒童課後照顧服務中心個人資料/對照表.pdf
# 《法規命令》行政院環境保護署公告：修正「應以網路傳輸方式申報廢棄物之產出、貯存、清除、處理、再利用、輸出及輸入情形之事業」，自108年1月1日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：修正「應以網路傳輸方式申報/《法規命令》行政院環境保護署公告：修正「應以網路傳輸方式申報廢棄物之產出、貯存、清除、處理、再利用、輸出及輸入情形之事業」，自108年1月1日生效.pdf
# 《法規命令》行政院環境保護署公告：修正「應檢具事業廢棄物清理計畫書之事業」，自108年1月1日生效.pdf
# ./Result/《法規命令》行政院環境保護署公告：修正「應檢具事業廢棄物清理/《法規命令》行政院環境保護署公告：修正「應檢具事業廢棄物清理計畫書之事業」，自108年1月1日生效.pdf
# 《法規命令》財政部公告：訂定金融機構屬「低風險規避稅負實體」名單，自即日生效.pdf
# ./Result/《法規命令》財政部公告：訂定金融機構屬「低風險規避稅負實體」/《法規命令》財政部公告：訂定金融機構屬「低風險規避稅負實體」名單，自即日生效.pdf
# 《法規命令》衛生福利部令：修正「全民健康保險醫療資源缺乏地區應具備之條件」，自108年1月1日生效.pdf
# ./Result/《法規命令》衛生福利部令：修正「全民健康保險醫療資源缺乏地區/《法規命令》衛生福利部令：修正「全民健康保險醫療資源缺乏地區應具備之條件」，自108年1月1日生效.pdf
# 總說明.pdf
# ./Result/《法規命令》客家委員會令：訂定「客語為通行語實施辦法」/總說明.pdf
# 對照表.pdf
# ./Result/《法規命令》客家委員會令：訂定「客語為通行語實施辦法」/對照表.pdf
